# %% [markdown]
# <a href="https://colab.research.google.com/github/bhaleghareakanksha/T170800233_TNSIF_AIML/blob/main/_AIML_day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
name = "Akanksha"
last_name='Bhaleghare'
print(name)
print(type(name))
print (last_name)
print(type(last_name))

age=21
abc = True
percentage= 85.97
print(age)
print(type(age))
print(abc)
print(type(abc))
print(percentage)
print(type(percentage))
print ("My name is",name ,"and last name is ", last_name, "and age is ", age)
# Out:
# Hello World
# Akanksha
# <class 'str'>
# Bhaleghare
# <class 'str'>
# 21
# <class 'int'>
# True
# <class 'bool'>
# 85.97
# <class 'float'>
# My name is Akanksha and last name is  Bhaleghare and age is  21

# %%
num = int(input ("Enter your num: "))
print (num)
print (type(num))
# Out:
# Enter your num: 12
# 12
# <class 'int'>

# %%
a = 7
b = 9
print (a+b)
print (a-b)
print (a*b)
print (a/b)
print (a**b)
print (a%b)
print (a//b)
# Out:
# 16
# -2
# 63
# 0.7777777777777778
# 40353607
# 7
# 0

# %%
#Comparision operator
a = 5
b = 7

print (a>b)
print (a<b)
print (a==b)
print (a<=b)
print (a>=b)
# Out:
# False
# True
# False
# True
# False

# %%
# Assignment Operater

a = 5
print (a)
a += 10
#a= a+ 10

print (a)
a -= 4
print (a)
#a= a-4

a *= 5
#a= a*5
print (a)

a /= 5
# a = a/5
print (a)
# Out:
# 5
# 15
# 11
# 55
# 11.0

# %%
text = "Python"
print("P" in text)
# Out:
# True

# %%
# Conditional Statements
# if , elif , else

a = 15
b = 12

if (a < b):
 print ("Hello")

elif (a > b):
  print ("Okay")

elif (a == b):
  print ("World")
else:
  print ("Bye")


if(a != b ):
  print ("Akanksha")
# Out:
# Okay
# Akanksha

# %%
for i in range(3):
  print(i)
# Out:
# 0
# 1
# 2

# %%
for i in range(8):
    if i == 3:
      break
      #continue
      #print(i)
    print(i)
# Out:
# 0
# 1
# 2

# %%
i = 34
while i < 50:
    print(i)
    break
    i += 1
# Out:
# 34

# %%
#Slicing

# %%
text = "Python is  a programming language"

print(text[0:3])   # Pyt
print(text[2:])    # thon
print(text[:4])    # Pyth
print(text[-1])    # n (last character)
print(text[::-1])  # Reverse string
# Out:
# Pyt
# thon is  a programming language
# Pyth
# e
# egaugnal gnimmargorp a  si nohtyP

# %%
text = "Python is  a programming language"
print(text.upper())  # PYTHON
print(text.lower())  # python
# Out:
# PYTHON IS  A PROGRAMMING LANGUAGE
# python is  a programming language

# %%
text = "  hello "
print(text)
print(text.strip())
# Out:
#   hello
# hello

# %%
text = "Hello World"
print(text.replace("World","Python"))
# Out:
# Hello Python

# %%
text = "Python is  a programming language"
print(text.split("a"))
# Out:
# ['Python is  ', ' progr', 'mming l', 'ngu', 'ge']

# %%
text = "Sneha"
print (len(text))
# Out:
# 5

# %%
#Functions

# %%
def greeting ():
  a=10
  b=20
  print(a+b)
  print ("Hello World")

greeting ()
# Out:
# 30
# Hello World

# %%
def details (First_Name):
  print (f"My name is {First_Name}")
  print ("my Name is ", First_Name)

details("Sneha")
# Out:
# My name is Sneha
# my Name is  Sneha

# %%
def add (x,y):
  print("The addition of 2 no is :", x+y)
  return x+y

result = add (5,6)
print (result)
add(10,30)
# Out:
# The addition of 2 no is : 11
# 11
# The addition of 2 no is : 40
# 40

# %%
#Keyword Arguments Function
def info(name, age, last_name):
    print(name, age,last_name)

info(age=21, name="Soham" , last_name="Patil")
info(age=34, name="Aditya" , last_name="Sharma")
# Out:
# Soham 21 Patil
# Aditya 34 Sharma

# %%
#multiple arguments functions
def add(*names):   #args
    print((names))

add(1,"Prachi",23.09, 23 , True)
add(1,2,3,4,5,6,7,8,9,0)
# Out:
# (1, 'Prachi', 23.09, 23, True)
# (1, 2, 3, 4, 5, 6, 7, 8, 9, 0)

# %%
#kwargs functions
def display(**details):
    print(details)

display(name="Kartik", age=21,address="Mumbai")
display(name="Kartik", age="Kartik",address="Mumbai")
# Out:
# {'name': 'Kartik', 'age': 21, 'address': 'Mumbai'}
# {'name': 'Kartik', 'age': 'Kartik', 'address': 'Mumbai'}

# %%
add = lambda a, b: a + b
print(add(2, 3))
# Out:
# 5

# %%
x = float(input("Enter value of x: "))
y = 2 * x + 3
print("Predicted y:", y)
# Out:
# Enter value of x: 2
# Predicted y: 7.0

# %%
temp = float(input("Enter temperature: "))

if temp > 30:
    print("Hot")
else:
    print("Normal")
# Out:
# Enter temperature: 23
# Normal

# %%
nums = []

for i in range(5):
    val = float(input("ENter No"))
    nums.append(val)

avg = sum(nums) / len(nums)
print("Average:", avg)
# Out:
# ENter No23
# ENter No21
# ENter No12
# ENter No12
# ENter No11
# Average: 15.8

# %%
#OOP

# %%
class Person:

   Name='Sneha'
   L_Name='Thorat'
   Roll_No=1001
   Barnch="AI & DS"
   print("abcde")
object1 = Person()
print(object1.Name, object1.L_Name, object1.Roll_No, object1.Barnch)
# Out:
# abcde
# Sneha Thorat 1001 AI & DS

# %%
class Dog:
  species = "Canine"

  def __init__(self, name, age):
    self.name = name
    self.age = age

dog1 = Dog("Buddy", 3)
dog2= Dog("Miky", 7)

print (dog1.name)
print (dog1.age)
print (dog1.species)
# Out:
# Buddy
# 3
# Canine

# %%
class Dog:
    species = "Canine"

    def __init__(self, name, age):
        self.name = name
        self.age = age

    def animal_name(self, dog, cat):
        self.dog = dog
        self.cat = cat
        print("Dog name:", self.dog)
        print("Cat name:", self.cat)
        print("Dog name of init fun ", self.name)

    def location(self, state, country):
        self.state = state
        self.country = country
        print("State:", self.state)
        print("Country:", self.country)

name = input("Enter dog object name: ")
age = int(input("Enter age: "))

dog_value = input("Enter dog name: ")
cat_value = input("Enter cat name: ")

d = Dog(name, age)
print (d.name)
print (d.age)
print (d.species)
d.animal_name(dog_value, cat_value)

d.location("Maharashtra", "India")
# Out:
# Enter dog object name: hero
# Enter age: 23
# Enter dog name: her
# Enter cat name: ruby
# hero
# 23
# Canine
# Dog name: her
# Cat name: ruby
# Dog name of init fun  hero
# State: Maharashtra
# Country: India

# %%
class car:
  def __init__(self, brand):
    self.brand = brand

  def show(self, colour):
    self.colour = colour
    print("Car colour : ", self.colour)
    print("Car Brand : ", self.brand)

  def display(self):
     print("Car colour : ", self.colour)
     print("Car Brand : ", self.brand )

c= car("Toyota")
c.show("Red")
c.display()
# Out:
# Car colour :  Red
# Car Brand :  Toyota
# Car colour :  Red
# Car Brand :  Toyota

# %%
class Details:

  def __init__(self, name, age, height, weight):
    self.name = name
    self.age = age
    self.height = height
    self.weight = weight
    print(f"The name of student is {self.name} and his age is {self.age}")
    print(f"The height of student is {self.height} and weight is {self.weight}" )



  def student(self):
    print(f"The name of student is {self.name} and his age is {self.age}")
    print(f"The height of student is {self.height} and weight is {self.weight}" )

  def person (self, id , roll_no):
    self.id = id
    self.roll_no = roll_no
    print (f"The id of student is {self.id} and roll no is {self.roll_no}and name of that student is {self.name}")
a = Details ("Rohan", 20, 175.67 , 60)
a.student()
a.person(1001, 10)
# Out:
# The name of student is Rohan and his age is 20
# The height of student is 175.67 and weight is 60
# The name of student is Rohan and his age is 20
# The height of student is 175.67 and weight is 60
# The id of student is 1001 and roll no is 10and name of that student is Rohan
